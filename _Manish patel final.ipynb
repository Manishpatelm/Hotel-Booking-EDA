# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name**            - Manish Patel

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Exploratory Data Analysis (EDA) is an important step in data science that involves the examination of a dataset to summarize its main characteristics, identify patterns, and build meaningful relationships between variables. In the context of hotel bookings, EDA can be used to explore the characteristics of hotel customers, such as their nationality and booking behavior, to gain insights into the market demand for different types of hotels, such as city or resort hotels.
#
# In python, the most common libraries used for EDA are pandas, matplotlib, and seaborn. Pandas is a powerful data manipulation library that allows us to load, process, and analyze data with ease. Matplotlib is a plotting library that provides a wide range of visualization tools, such as bar charts, histograms, and scatter plots, to help us visualize data. Seaborn is a statistical data visualization library that is built on top of matplotlib and provides more advanced visualization techniques.
#
# To start with EDA on a hotel booking dataset, we first loaded the data into a pandas DataFrame using the read_csv function. Then, we examined the structure of the data using the head and info methods. Next, we examined the presence of missing data in the dataset as missing data can affect the results of our analysis. We can use the isna method in pandas to identify the missing values, and then choose an appropriate method to handle them, before proceeding to analyze our data to gain insights.
#
# In conclusion, EDA is a critical step that helps us gain insights into the structure, patterns, and relationships in our data. In the context of hotel bookings, EDA can help us understand the market demand for different types of hotels, as well as the characteristics of hotel customers. By using python libraries such as pandas, matplotlib, and seaborn, we could efficiently perform EDA and visualize our findings in a meaningful way.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Analyzing hotel booking is extremely important for any business in the hospitality domain as it recognizes ways to make the business more profitable while improving guest satifaction.
#
# In the hospitality industry, guests are able to choose between different hotels. Hence in this highly competitive market, it is very important to understand the clients/guest's needs to provide them with the best service possible to attract more guests. The hotel industry is a very volatile and the bookings depend on various factors, including the hotel type, seasonality, day of the week, and many more. This makes analyzing the patterns available in the past data more important to help the hotels plan better. By analyzing historical data, hotels can predict their performance and can launch campaigns to boost their business.
#
# Hence, in this project, we have tried to analyse the different variables associated with hotel booking and discover some important insights that govern hotel bookings.
#
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things

# %% [markdown]
# #### **Objective of this Project**

# %% [markdown]
# The goal of this exploratory data analysis (EDA) project is to explore and analyze the data to draw useful insights and discover important factors that govern hotel bookings. We feel that such kind of EDA can help hotels to analyze their business models and modify them, if required.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px
import folium 
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/ almabetter csv file/Copy of Hotel Bookings.csv'

# %%
df1=pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df1.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df1.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df1[df1.duplicated()].shape
# Out:
# (31994, 32)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_values = df1.isnull().sum().sort_values(ascending=False).reset_index().rename(columns={'index':'Columns',0:'Number of Null values'})

# %%
null_values_pct = (df1.isna().sum().sort_values(ascending=False)*100)/len(df1)
null_values_pct = null_values_pct.reset_index().rename(columns={'index':'Columns',0:'% of Null values'})

# %%
pd.merge(null_values,null_values_pct)
# Out:
#                            Columns  Number of Null values  % of Null values
# 0                          company                 112593         94.306893
# 1                            agent                  16340         13.686238
# 2                          country                    488          0.408744
# 3                         children                      4          0.003350
# 4               reserved_room_type                      0          0.000000
# 5               assigned_room_type                      0          0.000000
# 6                  booking_changes                      0          0.000000
# 7                     deposit_type                      0          0.000000
# 8                            hotel                      0          0.000000
# 9           previous_cancellations                      0          0.000000
# 10            days_in_waiting_list                      0          0.000000
# ...

# %%
# Visualizing the missing values
plt.rcParams['figure.figsize'] = (10,8)
sns.barplot(x='% of Null values',y='Columns',data=null_values_pct)
plt.xlabel('% of missing values')
plt.ylabel('Column name')
plt.title("Missing value % by column")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This hotel booking dataset contains booking data of City and Resort hotels with 119390 rows and 32 columns.
#
# In the dataset there are 31994 rows with duplicate records.
#
# Moreover, there are four columns with null values. These columns are : company, agent, country, and children.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df1.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df1.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ***The description of the different columns present in this dataset are as follows:***
#
# * hotel
#   *  Resort hotel
#   *  City hotel
# * is_canceled
#   * 1: Canceled
#   * 0: Not canceled
# * lead_time: Number of days that elapsed between entering the date of booking into the property management system (PMS) and the arrival date
# * arrival_date_year
# * arrival_date_month
# * arrival_date_week_number
# * arrival_date_day_of_month
# * Day of arrival date
# * stays_in_weekend_nights: Number of weekend nights (Sat/Sun) the guest stayed or booked to stay at the hotel
# * stays_in_week_nights: Number of week nights (Mon - Fri) the guest stayed or booked to stay at the hotel
# * Adults
# * Children
# * Babies
# * meal:Type of meal booked. Includes:
#    * Undefined/SC – no meal package
#    * BB – Bed & Breakfast
#    * HB – Half board (breakfast and one other meal – usually dinner)
#   * FB – Full board (breakfast, lunch, and dinner)
# * country
# * market_segment
#   * TA: Travel agents
#   * TO: Tour operators
# * distribution_channel: A chain of businesses or intermediaries through which a good or service passes until it reaches the final buyer or the end consumer.
#   * TA: Travel agents
#   * TO: Tour operators
# * is_repeated_guest: Value indicating if the booking name was from a guest who have stayed at the hotel before
#   * 1: Yes
#   * 0: No
# * previous_cancellations: Number of previous bookings cancelled by the customer before the current booking
# * previous_bookings_not_canceled: Number of previous bookings not cancelled by the customer before the current booking
# * reserved_room_type: Code of the room type reserved. Code is presented instead of designation to maintain anonymity.
# * assigned_room_type: Code for the type of room assigned to the booking. Sometimes the assigned room type differs from the reserved room type due to hotel operation reasons (e.g. overbooking) or by customer request. Code is presented instead of designation to maintain anonymity.
# * booking_changes: Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation
# * deposit_type: Indication on if the customer made a deposit to guarantee the booking. This variable can assume three categories:
#   * No Deposit – no deposit was made
#   * Non Refund – a deposit was made in the value of the total stay cost
#   * Refundable – a deposit was made with a value under the total cost of stay.
# * agent: ID of the travel agency that made the booking
# * company: ID of the company/entity that made the booking or responsible for paying the booking. ID is presented instead of designation for anonymity reasons
# * day_in_waiting_list: Number of days the booking was in the waiting list before it was confirmed to the customer
# * customer_type
#   * Contract - when the booking has an allotment or other type of contract associated to it
#   * Group – when the booking is associated to a group
#   * Transient – when the booking is not part of a group or contract, and is not associated to other transient booking
#   * Transient-party – when the booking is transient, but is associated to at least other transient booking
# * adr (average daily rate): Indicates the average revenue earned for an occupied room on a given day
# * required_car_parking_spaces: Number of car parking spaces required by the customer
# * total_of_special_requests: Number of special requests made by the customer (e.g. twin bed or high floor)
# * reservation_status
#   * Canceled – booking was canceled by the customer;
#   * Check-Out – customer has checked in but already departed;
#   * No-Show – customer did not check-in and did inform the hotel of the reason why
# * reservation_status_date: Date at which the last status was set. This variable can be used in conjunction with the reservation_status to understand when was the booking canceled or when did the customer check-out of the hotel

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df1.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code
#
# **Cleaning and preparing the dataset**
#
# > Cleaning data is one of the most important part of EDA. Data cleaning entails many steps, including the following:
#
# 1.  Removing duplicate rows
# 2.  Handling missing or null values
# 3.  Converting data to appropriate data types
# 4.  Adding calculated columns to the dataset

# %%
# Write your code to make your dataset analysis ready.
df=df1.copy()

# %% [markdown]
# **Step-1: drop duplicate value**

# %%
#dropping the duplicate rows
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# **Step-2: Handling missing values**
# >1. We plan to drop the "company" column since it has ~94% null values.
# 2. For the "country" column, we plan to replace the missing values with "Others".
# 3. For the "children" column, we will replace the missing values with 0 .
# 4. For the "agents" column, we will replace null with 0, where agent ID = 0 represents that the guests booked the hotel themselves without the assistance of an agency.

# %%
# Dropping the "company" column
df.drop('company', axis= 1 ,inplace = True)

# %%
# Replacing all null values from "country" column to 'others' 
df['country'].fillna('others',inplace=True)

# Replacing all null values in "children" column to 0
df['children'].fillna(0 , inplace = True)

# Replacing all null values in "agent" column to 0
df['agent'].fillna(0 , inplace = True)

# %%
#Checking if all null values are removed
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %% [markdown]
# **Step-3 : Converting data to appropriate data type**
# > In the data info, we observed that the data in the "children" column is in float type. Hence, we plan to convert it to integer type.

# %%
#changing the data type
df['children'] = df['children'].astype('int64')

# %%
# Adding the "total_guest" column
df['total_guest'] = df['adults'] + df['children'] + df['babies']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87396 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87396 non-null  object
#  1   is_canceled                     87396 non-null  int64
#  2   lead_time                       87396 non-null  int64
#  3   arrival_date_year               87396 non-null  int64
#  4   arrival_date_month              87396 non-null  object
#  5   arrival_date_week_number        87396 non-null  int64
#  6   arrival_date_day_of_month       87396 non-null  int64
#  7   stays_in_weekend_nights         87396 non-null  int64
#  8   stays_in_week_nights            87396 non-null  int64
#  9   adults                          87396 non-null  int64
#  10  children                        87396 non-null  int64
#  11  babies                          87396 non-null  int64
# ...

# %%
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ## **Chart - 1 Which type of hotel genrally people prefer to book?**

# %%
# Chart - 1 visualization code
types_hotel=df['hotel'].value_counts().reset_index().rename(columns={'index':'Hotel Type', 'hotel':"Number of bookings"})

# %%
color = sns.color_palette('bright')
plt.pie(x=types_hotel['Number of bookings'], labels=types_hotel['Hotel Type'], colors=color, explode=[0,.1],autopct='%1.2f%%')
plt.title('Most preferred hotel', fontsize=18)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are useful for showing proportions of a whole as each slice represents a percentage of the total. They are easy to understand, visually appealing, and provide a clear representation of relative proportions.
#
# So we used pie chart to get the percentage comparison between City hotel and Resort hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >Through the above pie chart we get to know that city hotel is more preferred compared to resort hotel.
#
# >61.13 % guests have booked the city hotel while 38.87 % guests go with resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >The hotels can use this information to optimize their pricing and promotions. The more popular hotel may charge a premium for its services, while the less popular hotel may offer discounts or special promotions to attract more guests.
#
# >Based on the guest preferences, the hotels can allocate resources such as staff, inventory, and marketing budget to each hotel more effectively.

# %% [markdown]
# ## **Chart - 2 What is the percentage of cancellation of bookings.**

# %%
# Chart - 2 visualization code
palette_color = sns.color_palette('bright')
plt.pie(df['is_canceled'].value_counts(), labels=['Non Cancelled', 'Canceled'], colors=palette_color, explode=[0,.1],autopct='%1.2f%%')
plt.title("Percentage of canceled/non canceled bookings", fontsize=14)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >Pie charts are commonly used to display the proportion of different categories in a dataset. The advantage of using pie charts is that they are easily understood and provide a clear picture of the distribution of data.
#
# >Here we used this pie chart to get the percentage of cancellation rate by hotel type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >The percentages of canceled booking are 27.49%   non-canceled bookings are   72.51%

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >Drilling deeper to identify the reasons why customers cancel their hotel bookings can be used to reduce cancellation rates and improve customer satisfaction.

# %% [markdown]
# ## **Chart - 3 which types of customer doing more bookings**

# %%
non_canceled=df[df['is_canceled']==0]
customer_type=non_canceled['customer_type'].value_counts()
customer_type
# Out:
# Transient          50314
# Transient-Party     9940
# Contract            2627
# Group                490
# Name: customer_type, dtype: int64

# %%
# Chart - 3 visualization code
plt.figure(figsize=(12,6))
sns.barplot(x=customer_type.index, y=(customer_type.values*100)/non_canceled['customer_type'].count())
plt.xlabel("Customer Type", fontsize=14)
plt.ylabel('Percentage(%) of bookings', fontsize=14)
plt.title("Percentage of bookings by customer type", fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >A bar chart is a type of graph that represents data using rectangular bars. Each bar represents a category, and the length of the bar represents the value of the data for that category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >Here we can see that Transient types of customer doing more bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >Transient customers often contribute to a steady stream of revenue for hotels. By analyzing their booking patterns, you can identify peak seasons or periods of high demand.
#
# > Managing a high volume of transient customers requires efficient operational processes. Analyzing guest check-in and check-out patterns can help optimize staffing levels, streamline front desk operations, and reduce waiting times.

# %% [markdown]
# ## **Chart - 4 Which type of deposit is more preferred by the customers?**

# %%
deposit_type=df['deposit_type'].value_counts()
deposit_type
# Out:
# No Deposit    86251
# Non Refund     1038
# Refundable      107
# Name: deposit_type, dtype: int64

# %%
# Chart - 4 visualization code
plt.figure(figsize=(14,7))
plt.pie(x=deposit_type.values, labels=deposit_type.index,colors=palette_color,  explode=[0,0.1,0], autopct='%1.1f%%')
plt.legend( labels=deposit_type.index, loc='best')
plt.title('Percentage(%) of Deposit Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >Pie charts are commonly used to display the proportion of different categories in a dataset. The advantage of using pie charts is that they are easily understood and provide a clear picture of the distribution of data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we can see than 98.7% of customer coose no deposit and 1.2% customer choose non refund and 0.1% customers choose Refundable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >The absence of a deposit requirement can make your hotel more appealing to potential customers. Many travelers appreciate the flexibility and convenience of not having to pay a deposit upfront, which can lead to increased bookings and higher occupancy rates. This can be especially advantageous if your competitors still require deposits.
#
# >Risk of Cancellations and No-Shows
#
# >Impact on Cash Flow: With no deposits, your hotel may face challenges in managing cash flow effectively. Deposits often serve as a way to secure some funds upfront and help cover operational costs.

# %% [markdown]
# ## **Chart - 5Which kind of food is mostly preffered by the guests?**

# %%
# Chart - 5 visualization code
plt.figure(figsize=(12,6))
sns.countplot(x=non_canceled['meal'])
plt.xlabel('Meal Type')
plt.ylabel('Number of customers')
plt.title('Most preffered food type', fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# here we can see that BB (Bed & Breakfast) food customer order more .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >This information can be valuable for hotel owners as they can use it to tailor their offerings and improve customer satisfaction. For example, they could invest in offering a wider range of breakfast options or improving the quality of the breakfast.

# %% [markdown]
# ## **Chart - 6 From which country mostly guests are coming from?**

# %%
# Chart - 6 visualization code
guest_country=non_canceled['country'].value_counts().reset_index().rename(columns={'index':'Country', 'country':'Number of Guests'})
plt.figure(figsize=(16,7))
sns.barplot(x=guest_country['Country'].head(15), y=guest_country['Number of Guests'].head(15))
plt.title("Number of guests from the different Countries", fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# >A bar chart is a type of graph that represents data using rectangular bars. Each bar represents a category, and the length of the bar represents the value of the data for that category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >Most of the visitor from Purtagal and Great Britain .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >This information can be used by hotel owners to improve their marketing efforts and better target customers in this specific country.

# %% [markdown]
# ## **Chart - 7 What is the most preferred room type?**

# %%
# Chart - 7 visualization code
plt.figure(figsize=(12,6))
sns.countplot(x=non_canceled['assigned_room_type'])
plt.xlabel("Assigned Room Type")
plt.ylabel("Number of guests")
plt.title("Most preferred room types by the guests", fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The countplot is used to represent the occurrence(counts) of the observation present in the categorical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >Room type A,D and E is the most preferred room.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >Since Room type A is the most preferred room, hotels can prepare more rooms of type A in the peak seasons to ensure that the customers get the room of their choice when the demand is high.

# %% [markdown]
# ## **Chart - 8 How much guests pay for a room per night?**

# %%
# Chart - 8 visualization code
plt.figure(figsize=(12,6))
sns.boxplot(x='reserved_room_type', y='adr', data=non_canceled, hue='hotel')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot is a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile [Q1], median, third quartile [Q3] and “maximum”). It can tell you about your outliers and what their values are.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >For non-canceled bookings, room type H shows the highest median ADR for Resort hotel while room type G shows the highest median ADR for City hotel.
#
# However, there is great variation in the ADR of most room types as seen from the plot.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >This insight has the potential to have a significant positive impact on the hotels' revenue. Knowing which room type generates the highest median ADR for each hotel allows the hotels to optimize their pricing strategy for these rooms.
#
# >For example, the hotel may choose to increase the prices for room type H in the Resort hotel or room type G in the City hotel, as these rooms generate the most revenue. Additionally, the hotels can allocate more resources to improve the guest experience in these high-performing rooms, which can further increase their popularity and drive more bookings.

# %% [markdown]
# ##**Chart - 9 How long people stays in hotel?**

# %%
df['Total nights']=df['stays_in_weekend_nights']+df['stays_in_week_nights']

# %%
total_nights=df['Total nights'].value_counts().sort_index()
total_nights.head(10)
# Out:
# 0      651
# 1    17184
# 2    15745
# 3    17839
# 4    13575
# 5     6742
# 6     3271
# 7     7527
# 8     1067
# 9      780
# Name: Total nights, dtype: int64

# %%
# Chart - 9 visualization code
plt.figure(figsize=(12,6))
plt.plot(total_nights)
plt.xlabel("Number of days")
plt.ylabel('Number of bookings')
plt.title('Total number of nights', fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  A line chart is a graphical representation of an asset's historical price action that connects a series of data points with a continuous line.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most of the customer live 1,2 or 3 days.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Most of the customer live 1,2 or 3 days. according to that we  Forge partnerships with local businesses, such as restaurants, tourist attractions, or transportation services, to offer bundled packages or discounts to your guests. This collaboration can attract more short-term guests who are seeking convenience and value during their stay.

# %% [markdown]
# ## **Chart - 10 What is the most commenly used distribution channel for hotel bookings?**

# %%
# Chart - 10 visualization code
booking_channel=df['distribution_channel'].value_counts().reset_index().rename(columns={'index':'Distribution Channel','distribution_channel':'Number of bookings'})
color = sns.color_palette('Paired')
plt.figure(figsize=(12,6))
plt.pie(x=booking_channel['Number of bookings'].head(4), labels=booking_channel['Distribution Channel'].head(4),colors=palette_color, explode=[0,0,0,.5], autopct='%1.1f%%')
plt.title('Disribution channel used for bookings', fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie charts are commonly used to visualize data that represents parts of a whole. They are particularly useful when you want to show the proportion or distribution of different categories or components within a dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >TA/TO is mostly (82%) used for booking hotels

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We have to build strong relationships with travel agents and travel operators to establish a mutually beneficial partnership. Regularly communicate with them, provide support, and address any concerns promptly. A positive relationship can lead to increased bookings and recommendations.

# %% [markdown]
# ## **Chart - 13 - Correlation Heatmap**

# %%
# Chart - 11 visualization code
plt.figure(figsize=(18,13))
columns_df= df[['lead_time','total_guest','Total nights','is_repeated_guest','booking_changes','days_in_waiting_list','adr',
       'required_car_parking_spaces', 'total_of_special_requests']]
sns.heatmap(columns_df.corr(),annot=True,fmt = '.2f',cmap= 'BuGn_r')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is a graphical representation of the correlation between multiple variables. It is used to visualize the relationship between two or more variables and to identify any patterns or trends in the data. The heatmap typically uses color coding to indicate the strength of the correlation. This type of heatmap is commonly used in data analysis to help identify relationships between variables and to guide decision-making.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# >Total_nights and lead time have slight correlation in it. This might means for longer stay customers plan reservation little before their actual arrival.
#
# >Adr is slightly correlated with total guest, which is showing more number of guest means more revenue.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# *   Encourage customers to provide feedback through surveys and reviews. This will provide valuable insights into the customer experience and help identify areas for improvement.
#
# *   Develop a recommendation engine based on the data analysis that can suggest the best time to book, the most popular room types, and the best promotions to attract customers.
#
# *   Based on the insights gained from the analysis, develop targeted marketing campaigns to reach the desired customer segments.
#
# *   Continuously monitor the data and make adjustments to the marketing strategies as required. This will ensure that the hotel stays ahead of the competition and meets its business objectives.
#
# *   Tailor marketing and customer service strategies to better serve the different segments of the customer base.
#
# *   Adjust the pricing, staffing, and inventory management strategies to better meet customer demand during peak and off-peak periods.
# Set competitive prices and maximize revenue.
#
# *   Identify and reward loyal customers and improve customer retention to drive repeat business.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# >In this notebook, we analysed the comprehensive data on hotel booking analysis and tried to unearth various insights from the data. We used the pandas library to do the analyses and used matplotlib, seaborn, and plotly to visualize the data. Here are the insights we obtained from the data:
#
# *   Overall, 59.1 % people prefer city hotel and 40.9 % people prefer resort hotel.
# *   Along with higher booking count, city hotels also have a higher cancellation rate than resort hotels (cancellation rate of city and resort hotels are 30.2 % and 23.7 %, respectively).
# *   There is a positive correlation between cancelation and lead time, meaning higher the lead time, higher the chances that the booking will be canceled by the guest/agent.
# *   Room type A is the most preferred room in both city and resort hotels.
# *   City hotel has higher mean adr than resort hotels. Also, the adr of most of the room types vary a lot and is likely affected by different factors, like demand, time of year, guest count, and so on, which can be looked at further.
# *   The highest booking counts are observed in the months of March-June and in August-October.
# *   Most of the guests are from Portugal.
# *   Agent/Agency Number 9 has done the most number of bookings.
# *   Bed & Breakfast meal type is most prefered.
# *   The percentage of repeated guests is higher in resort hotels than in city hotels.
#
# > These are just a few of the many insights that could be obtained from an EDA of hotel booking data. By leveraging the power of data, hotels can make informed decisions that drive growth and improve customer satisfaction.

# %% [markdown]
# ### ***THE END***
